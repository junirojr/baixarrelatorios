# %% [markdown]
# Importando as bibliotecas

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import pyautogui
import time
import datetime as dt

servico = Service(ChromeDriverManager().install())
date = dt.date.today()
tresmesesatras =  date.fromordinal(date.toordinal()-90)
tresmesesatras = tresmesesatras.strftime('%d/%m/%Y')
seismesesatras = date.fromordinal(date.toordinal()-183)
seismesesatras = seismesesatras.strftime('%d/%m/%Y')
dozemesesatras = date.fromordinal(date.toordinal()-365)
dozemesesatras = dozemesesatras.strftime('%d/%m/%Y')

# %%
print(dozemesesatras)
# Out:
# 28/12/2022

# %% [markdown]
# Abrindo PipeDrive e baixando os relatórios

# %%
navegador = webdriver.Chrome(service = servico)
#Abrindo site pipe driver
navegador.get("https://app.pipedrive.com/auth/login") #Abre navegador no pipedrive
#Entrando no pipedriver
navegador.find_element('xpath','//*[@id="login"]').send_keys("manoel@trimaf.com") #Localiza a parte do email e insere o login
navegador.find_element('xpath','//*[@id="password"]').send_keys("Pingo1973") # Localiza a parte da senha e insere a mesma
navegador.find_element('xpath','//*[@id="root"]/div/div/section/div/div/div[1]/div/div/div/form/div/div[3]/button').click() # clica para fazer login
time.sleep(5)
navegador.find_element('xpath','/html/body/div[1]/nav/ul/li[3]/a').click()
time.sleep(15)
#navegador.find_element('xpath','//*[@id="pageContainer"]/div[1]/div[2]/div[2]/span').click() # busca os 3 pontinhos para exportar 
navegador.find_element('xpath','//*[@class="input selectSettings"]').click()
time.sleep(1)
navegador.find_element('xpath','//*[@class="exportResults"]').click()
#pyautogui.click(x=1255, y=402) # clica em exportar
time.sleep(0.5)
navegador.find_element('xpath','//*[@id="modal"]/div[2]/div/div/div/form/div[1]/label').click()
#navegador.find_element('xpath','//*[@id="export-format-xlsx"]').click()# seleciona a opção xlsx 
#pyautogui.click(x=537, y=375) # seleciona a opção xlsx 
time.sleep(0.5)
navegador.find_element('xpath','//*[@id="modal"]/div[2]/footer/div/span[3]').click() # clica em exportar após selecionar xlxs
#pyautogui.click(x=1037, y=522) # clica em exportar após selecionar xlxs
time.sleep(25)
navegador.find_element('xpath','//*[@id="modal"]/div[2]/div/div/div/div[2]/p[2]/span').click()
#pyautogui.click(x=809, y=383) #clica em baixar
time.sleep(3)
navegador.find_element('xpath','/html/body/div[1]/nav/ul/li[8]/a').click() # Abre organizações
time.sleep(5)
#navegador.find_element('xpath','//*[@id="pageContainer"]/div[1]/div[2]/div[2]/span').click() # busca os 3 pontinhos para exportar 
pyautogui.click(x=1539, y=347)#clica nos 3 pontinho
time.sleep(1)
navegador.find_element('xpath','//*[@class="exportResults"]').click()
#pyautogui.click(x=1255, y=402) # clica em exportar
time.sleep(0.5)
navegador.find_element('xpath','//*[@id="export-format-xlsx"]').click()# seleciona a opção xlsx 
#pyautogui.click(x=537, y=375) # seleciona a opção xlsx 
time.sleep(1)
navegador.find_element('xpath','//*[@id="modal"]/div[2]/footer/div/span[3]').click()# clica em exportar após selecionar opção do arquivo
time.sleep(15)
navegador.find_element('xpath','//*[@id="modal"]/div[2]/div/div/div/div[2]/p[2]/span').click()# clica em baixar
#pyautogui.click(x=809, y=383) #clica em baixar
time.sleep(5)
navegador.quit()
#pyautogui.click(x=1255, y=402) # clica em exportar
#time.sleep(0.5)
#pyautogui.click(x=537, y=375) # seleciona a opção xlsx 
#time.sleep(0.5)
#pyautogui.click(x=1037, y=522) # clica em exportar após selecionar xlxs

# %% [markdown]
# Abrindo o uniplus

# %%
'''time.sleep(1)
pyautogui.press("win")
time.sleep(1)
pyautogui.write("Uniplus")
time.sleep(1)
pyautogui.press("enter") #Abre o uniplus
time.sleep(5)
pyautogui.click(x=955, y=569) #Entra no uniplus
time.sleep(5)
pyautogui.click(x=968, y=77) #Clica no nome da trimaf para selecionar a filial
time.sleep(1)
pyautogui.click(x=1195, y=518) #Clica em selecionar filial
time.sleep(1)
pyautogui.click(x=1013, y=591) #Seleciona a filial 1
time.sleep(1)
pyautogui.click(x=895, y=635) #Aplica
time.sleep(3)
#Baixar Produtos F1
pyautogui.click(x=156, y=136) #Clica em cadastros
pyautogui.click(x=156, y=136) #Clica em cadastros
time.sleep(3)
pyautogui.click(x=154, y=398) #Clica em produtos
time.sleep(1)
pyautogui.click(x=351, y=989) #Clica em visão
time.sleep(1)
pyautogui.click(x=1148, y=429) # clica em selecionar opção
time.sleep(1)
pyautogui.click(x=832, y=627) #seleciona "Visão Relatório"
time.sleep(1)
pyautogui.click(x=982, y=492) #clica em aplicar
time.sleep(2)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(5)
#Baixar Clientes F1
pyautogui.click(x=156, y=136) #Clica em cadastros
time.sleep(3)
pyautogui.click(x=90, y=254) #Clica em cliente
time.sleep(1)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(5)
# Orçamentos de Faturamento F1
pyautogui.click(x=532, y=140) #Clica em Vendas
time.sleep(3)
pyautogui.click(x=279, y=343) #Clica em orçamentos de faturamento
time.sleep(1)
pyautogui.click(x=1054, y=243) #Clica em filtro
time.sleep(1)
pyautogui.click(x=760, y=449) #Clica em opção de faturamento
time.sleep(1)
pyautogui.write('t')
time.sleep(1)
pyautogui.click(x=739, y=524) #Clica em data
time.sleep(1)
pyautogui.press("backspace")
time.sleep(1)
pyautogui.click(x=843, y=616)
time.sleep(1)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(5)
#Pedidos de faturamento F1
pyautogui.click(x=532, y=140) #Clica em Vendas
time.sleep(3)
pyautogui.click(x=209, y=385) #Clica em Pedidos de faturamento
time.sleep(1)
pyautogui.click(x=1054, y=243) #Clica em filtro
time.sleep(1)
pyautogui.click(x=760, y=449) #Clica em opção de faturamento
pyautogui.write('t')
pyautogui.click(x=739, y=524) #Clica em data
pyautogui.press("backspace")
pyautogui.click(x=843, y=616)
time.sleep(1)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(5)
# Nota fiscal entrada F1
pyautogui.click(x=728, y=135) #Clica em Fiscal

time.sleep(3)
pyautogui.click(x=267, y=432) #Clica em Nota fiscal de entrada
time.sleep(3)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(5)
#Nota fical saída F1
pyautogui.click(x=728, y=135) #Clica em Fiscal
time.sleep(2)
pyautogui.click(x=212, y=477) #Clica em Nota fiscal de saida
time.sleep(3)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(5)
#Vendas produtos periodo 2023 xlsx
pyautogui.click(x=532, y=140) #Clica em Vendas
time.sleep(3)
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
time.sleep(1)
pyautogui.click(x=814, y=659) #Clica em Vendas de produtos no periodo
time.sleep(1)
pyautogui.click(x=479, y=356) #Clica em selecionar filial
pyautogui.click(x=213, y=397) #Seleciona filia 1
pyautogui.click(x=213, y=439) #Seleciona filia 2
pyautogui.press('tab') #Aperta tab 
pyautogui.press('tab') #Aperta tab
pyautogui.write('01012023') #Escreve a data
pyautogui.click(x=1576, y=592) #clica em "Mês"
pyautogui.click(x=321, y=959) #clica em excel
pyautogui.click(x=732, y=966) #clica em xlsx
pyautogui.click(x=1725, y=956) #clica em gerar
time.sleep(10)
#Posição estoque 
pyautogui.click(x=911, y=137) #Clica em estoque
time.sleep(3)

pyautogui.click(x=952, y=565) #Clica em Posição estoque
time.sleep(2)
pyautogui.click(x=479, y=356) #Clica em selecionar filial
pyautogui.click(x=213, y=397) #Seleciona filia 1
pyautogui.click(x=213, y=439) #Seleciona filia 2
time.sleep(1)
pyautogui.click(x=321, y=959) #clica em excel
pyautogui.click(x=732, y=966) #clica em xlsx
time.sleep(1)
pyautogui.click(x=1725, y=956) #clica em gerar
# Out:
#   Cell In[4], line 1
#     '''time.sleep(1)
#     ^
# SyntaxError: incomplete input

# %%
'''time.sleep(10)
#Download Giro estoque
pyautogui.click(x=911, y=137) #Clica em estoque
time.sleep(3)
pyautogui.click(x=874, y=389) #Clica em Giro estoque
time.sleep(1)
pyautogui.click(x=171, y=355) # Clica em Ano
pyautogui.write("2023")
time.sleep(1)
pyautogui.click(x=519, y=428) #Clica em selecionar filial
time.sleep(1)
pyautogui.click(x=213, y=467) #Seleciona filia 1
time.sleep(0.5)
pyautogui.click(x=213, y=514) #Seleciona filia 2
time.sleep(1.5)
pyautogui.click(x=321, y=959) #clica em excel
pyautogui.click(x=732, y=966) #clica em xlsx
pyautogui.click(x=1725, y=956) #clica em gerar

'''#Download produtos em orçamento
'''time.sleep(15)
pyautogui.click(x=532, y=140) #Clica em Vendas
time.sleep(1.5)
pyautogui.click(x=1894, y=188) #Clica em rolar a tela
pyautogui.click(x=1894, y=188) #Clica em rolar a tela
pyautogui.click(x=1894, y=188) #Clica em rolar a tela
pyautogui.click(x=1894, y=188) #Clica em rolar a tela
pyautogui.click(x=1894, y=188) #Clica em rolar a tela

time.sleep(1.5)
pyautogui.click(x=837, y=558) #Clica em Produtos em orçamento
pyautogui.click(x=914, y=649) #Clica em selecionar filial
pyautogui.click(x=441, y=706) #Seleciona Filial 1
pyautogui.click(x=321, y=959) #clica em excel
pyautogui.click(x=732, y=966) #clica em xlsx
pyautogui.click(x=1725, y=956) #clica em gerar
time.sleep(10)
pyautogui.click(x=914, y=649) #Clica em selecionar filial
pyautogui.click(x=441, y=799) #Seleciona Filial 2
pyautogui.click(x=321, y=959) #clica em excel
pyautogui.click(x=732, y=966) #clica em xlsx
pyautogui.click(x=1725, y=956) #clica em gerar'''

#Vendas de produtos no periodo xls
'''time.sleep(10)
pyautogui.click(x=532, y=140) #Clica em Vendas
time.sleep(3)
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
pyautogui.click(x=1893, y=891) #Clica em rolar a tela
time.sleep(1)
pyautogui.click(x=814, y=659) #Clica em Vendas de produtos no periodo
time.sleep(1)

pyautogui.click(x=1576, y=592) #clica em "Mês"
pyautogui.click(x=212, y=357) #Clica em selecionar filial
time.sleep(1)
pyautogui.click(x=213, y=393) #Seleciona filia 1
time.sleep(0.5)
pyautogui.click(x=213, y=432) #Seleciona filia 2
time.sleep(1.5)
pyautogui.press('tab') #Aperta tab 
pyautogui.press('tab') #Aperta tab
#Ano corrente 
pyautogui.write('01012023') #Escreve a data
time.sleep(1)
pyautogui.click(x=321, y=959) #clica em excel
pyautogui.click(x=582, y=957) #clica em xls
time.sleep(1)
pyautogui.click(x=1725, y=956) #clica em gerar
time.sleep(10)
# Três Meses 
pyautogui.click(x=328, y=428) #Clica em data inicial
pyautogui.write(tresmesesatras)
pyautogui.click(x=321, y=959) #clica em excel
pyautogui.click(x=582, y=957) #clica em xls
time.sleep(1)
pyautogui.click(x=1725, y=956) #clica em gerar
time.sleep(10)
# Seis meses 
pyautogui.click(x=328, y=428) #Clica em data inicial
pyautogui.write(seismesesatras)
pyautogui.click(x=321, y=959) #clica em excel
pyautogui.click(x=582, y=957) #clica em xls
time.sleep(1)
pyautogui.click(x=1725, y=956) #clica em gerar
time.sleep(10)
# Doze meses
pyautogui.click(x=328, y=428) #Clica em data inicial
pyautogui.write(dozemesesatras)
pyautogui.click(x=321, y=959) #clica em excel
pyautogui.click(x=582, y=957) #clica em xls
time.sleep(1)
pyautogui.click(x=1725, y=956) #clica em gerar
time.sleep(10)

time.sleep(10)
# Filial 2
pyautogui.click(x=968, y=77) #Clica no nome da trimaf para selecionar a filial
time.sleep(1)
pyautogui.click(x=1195, y=518) #Clica em selecionar filial
time.sleep(1)
pyautogui.click(x=924, y=657) #Seleciona a filial 2
time.sleep(1)
pyautogui.click(x=895, y=635) #Aplica
time.sleep(3)
# Produtos F2
pyautogui.click(x=156, y=136) #Clica em cadastros
pyautogui.click(x=156, y=136) #Clica em cadastros
time.sleep(3)
pyautogui.click(x=154, y=398) #Clica em produtos filial 2
time.sleep(1)
pyautogui.click(x=351, y=989) #Clica em visão
time.sleep(1)
pyautogui.click(x=1148, y=429) # clica em selecionar opção
time.sleep(1)
pyautogui.click(x=832, y=627) #seleciona "Visão Relatório"
time.sleep(1)
pyautogui.click(x=982, y=492) #clica em aplicar
time.sleep(2)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(10)
#orçamentos de faturamento filia 2
pyautogui.click(x=532, y=140) #Clica em Vendas
time.sleep(3)
pyautogui.click(x=279, y=343) #Clica em orçamentos de faturamento filia 2
time.sleep(1)
pyautogui.click(x=1054, y=243) #Clica em filtro
time.sleep(1)
pyautogui.click(x=760, y=449) #Clica em opção de faturamento
time.sleep(1)
pyautogui.write('t')
time.sleep(1)
pyautogui.click(x=739, y=524) #Clica em data
time.sleep(1)
pyautogui.press("backspace")
time.sleep(1)
pyautogui.click(x=843, y=616)
time.sleep(1)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(10)
#Pedidos de faturamento f2
pyautogui.click(x=532, y=140) #Clica em Vendas
time.sleep(3)
pyautogui.click(x=209, y=385) #Clica em Pedidos de faturamento 2
time.sleep(1)
pyautogui.click(x=1054, y=243) #Clica em filtro
time.sleep(1)
pyautogui.click(x=760, y=449) #Clica em opção de faturamento
pyautogui.write('t')
pyautogui.click(x=739, y=524) #Clica em data
pyautogui.press("backspace")
pyautogui.click(x=843, y=616)
time.sleep(1)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(10)
#Nota fiscal de entrada F2
pyautogui.click(x=728, y=135) #Clica em Fiscal

time.sleep(3)
pyautogui.click(x=267, y=432) #Clica em Nota fiscal de entrada 2
time.sleep(3)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(10)
#Nota fiscal de saida F2
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(5)
pyautogui.click(x=728, y=135) #Clica em Fiscal
time.sleep(2)
pyautogui.click(x=212, y=477) #Clica em Nota fiscal de saida 2
time.sleep(3)
pyautogui.click(x=116, y=986) #Clica em baixar
time.sleep(3)
pyautogui.click(x=881, y=498) #Clica em exportar
time.sleep(5)

#pyautogui.click(x=1885, y=22)

time.sleep(5)
pyautogui.position()
